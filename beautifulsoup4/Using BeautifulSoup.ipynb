# %%
import requests

# %%
url = "https://www.pagina12.com.ar/"

# %%
# Generar una solicitud y almacenarla
p12 = requests.get(url)

# %%
# Objeto
p12
# Out:
# <Response [200]>

# %%
# Status: 200 OK
p12.status_code
# Out:
# 200

# %%
print(p12.text)
# Out:
# <!DOCTYPE html><html class="no-js"><head><meta charset="utf-8"><title>Página12 | La otra mirada</title><meta name="google-site-verification" content="x6zSdT0DBcKDmridH4LpEVrCmxcOunR2dgBQVmuL6fg"><script type="application/ld+json">{"@context": "http://schema.org","@type": "Organization","url": "https://www.pagina12.com.ar","logo": "https://www.pagina12.com.ar/assets/media/logo_default_p12.png"}</script><meta property="description" name="description" content="Notas focalizadas en el quehacer político de la Argentina."><meta property="fb:pages" name="fb:pages" content="1541638399393436"><meta property="og:locale" name="og:locale" content="es_AR"><meta property="og:title" name="og:title" content="Página12 | La otra mirada"><meta property="og:site_name" name="og:site_name" content="PAGINA12"><meta property="og:type" name="og:type" content="website"><meta property="og:url" name="og:url" content="https://www.pagina12.com.ar"><meta property="og:description" name="og:description" content="Not
# ...

# %%
# What kind of information type is?
p12.content
# Out:
# b'<!DOCTYPE html><html class="no-js"><head><meta charset="utf-8"><title>P\xc3\xa1gina12 | La otra mirada</title><meta name="google-site-verification" content="x6zSdT0DBcKDmridH4LpEVrCmxcOunR2dgBQVmuL6fg"><script type="application/ld+json">{"@context": "http://schema.org","@type": "Organization","url": "https://www.pagina12.com.ar","logo": "https://www.pagina12.com.ar/assets/media/logo_default_p12.png"}</script><meta property="description" name="description" content="Notas focalizadas en el quehacer pol\xc3\xadtico de la Argentina."><meta property="fb:pages" name="fb:pages" content="1541638399393436"><meta property="og:locale" name="og:locale" content="es_AR"><meta property="og:title" name="og:title" content="P\xc3\xa1gina12 | La otra mirada"><meta property="og:site_name" name="og:site_name" content="PAGINA12"><meta property="og:type" name="og:type" content="website"><meta property="og:url" name="og:url" content="https://www.pagina12.com.ar"><meta property="og:description" name="og:de
# ...

# %%
# More information about it...
p12.headers
# Out:
# {'Date': 'Wed, 23 Sep 2020 00:19:43 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Set-Cookie': '__cfduid=d3977e089b8dc2e1756d1172bb9cb36761600820383; expires=Fri, 23-Oct-20 00:19:43 GMT; path=/; domain=.pagina12.com.ar; HttpOnly; SameSite=Lax', 'Vary': 'Accept-Encoding', 'X-DNS-Prefetch-Control': 'off', 'Strict-Transport-Security': 'max-age=15724800; includeSubDomains', 'X-Download-Options': 'noopen', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '1; mode=block', 'X-ETag': 'W/"5d9a3-RNS/yiAh8517vvNjDjCgGLOzAqw"', 'X-Backend': 'frontend', 'X-Backend-TTL': '180.000', 'X-Type': 'Dynamic URI', 'Age': '0', 'grace': '86400.000 none', 'ttl': '119.659', 'X-Instance': 'cache-front-prod-varnish-6f54cb8b98-4khw7', 'x-restarts': '0', 'X-Cache': 'HIT (4)', 'CF-Cache-Status': 'DYNAMIC', 'cf-request-id': '0559eda5ae0000b3762c92d200000001', 'Expect-CT': 'max-age=604800, report-uri="https://report-uri.cloudflare.com/cdn-cgi/b
# ...

# %%
# Information about who made the request
# This can be modified, it would be teached later
p12.request.headers
# Out:
# {'User-Agent': 'python-requests/2.24.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}

# %%
p12.request.method
# Out:
# 'GET'

# %%
p12.request.url
# Out:
# 'https://www.pagina12.com.ar/'

# %%
from bs4 import BeautifulSoup

# %%
s = BeautifulSoup(p12.text, 'lxml')

# %%
# Verificando el tipo de dato de s
type(s)
# Out:
# bs4.BeautifulSoup

# %%
print(s.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Página12 | La otra mirada
#   </title>
#   <meta content="x6zSdT0DBcKDmridH4LpEVrCmxcOunR2dgBQVmuL6fg" name="google-site-verification"/>
#   <script type="application/ld+json">
#    {"@context": "http://schema.org","@type": "Organization","url": "https://www.pagina12.com.ar","logo": "https://www.pagina12.com.ar/assets/media/logo_default_p12.png"}
#   </script>
#   <meta content="Notas focalizadas en el quehacer político de la Argentina." name="description" property="description"/>
#   <meta content="1541638399393436" name="fb:pages" property="fb:pages"/>
#   <meta content="es_AR" name="og:locale" property="og:locale"/>
#   <meta content="Página12 | La otra mirada" name="og:title" property="og:title"/>
#   <meta content="PAGINA12" name="og:site_name" property="og:site_name"/>
#   <meta content="website" name="og:type" property="og:type"/>
# ...

# %%
s.find('ul')
# Out:
# <ul class="horizontal-list main-supplements"><li><span class="today">Hoy:</span></li><li class="p12-separator--right--primary"><a href="https://www.pagina12.com.ar/suplementos/no">NO</a></li><li class=""><a href="https://www.pagina12.com.ar/suplementos/soy">Soy</a></li></ul>

# %%
type(s.find('ul'))
# Out:
# bs4.element.Tag

# %%
s.find('ul', attrs={'class':'horizontal-list main-sections hide-on-dropdown'})
# Out:
# <ul class="horizontal-list main-sections hide-on-dropdown"><li class="p12-separator--right--primary"><a href="https://www.pagina12.com.ar/secciones/el-pais">El país</a></li><li class="p12-separator--right--primary"><a href="https://www.pagina12.com.ar/secciones/la-ventana">La ventana</a></li><li class="p12-separator--right--primary"><a href="https://www.pagina12.com.ar/secciones/economia">Economía</a></li><li class="no-separator-on-1040 p12-separator--right--primary"><a href="https://www.pagina12.com.ar/secciones/sociedad">Sociedad</a></li><li class="hide-on-1040 p12-separator--right--primary"><a href="https://www.pagina12.com.ar/suplementos/cultura-y-espectaculos">Cultura y Espectáculos</a></li><li class="hide-on-1040 p12-separator--right--primary"><a href="https://www.pagina12.com.ar/secciones/el-mundo">El mundo</a></li><li class="hide-on-1040 p12-separator--right--primary"><a href="https://www.pagina12.com.ar/secciones/deportes">Deportes</a></li><li class="hide-on-1040"><a href="h
# ...

# %%
s.find('ul', attrs={'class':'horizontal-list main-sections hide-on-dropdown'}).find_all('li')
# Out:
# [<li class="p12-separator--right--primary"><a href="https://www.pagina12.com.ar/secciones/el-pais">El país</a></li>,
#  <li class="p12-separator--right--primary"><a href="https://www.pagina12.com.ar/secciones/la-ventana">La ventana</a></li>,
#  <li class="p12-separator--right--primary"><a href="https://www.pagina12.com.ar/secciones/economia">Economía</a></li>,
#  <li class="no-separator-on-1040 p12-separator--right--primary"><a href="https://www.pagina12.com.ar/secciones/sociedad">Sociedad</a></li>,
#  <li class="hide-on-1040 p12-separator--right--primary"><a href="https://www.pagina12.com.ar/suplementos/cultura-y-espectaculos">Cultura y Espectáculos</a></li>,
#  <li class="hide-on-1040 p12-separator--right--primary"><a href="https://www.pagina12.com.ar/secciones/el-mundo">El mundo</a></li>,
#  <li class="hide-on-1040 p12-separator--right--primary"><a href="https://www.pagina12.com.ar/secciones/deportes">Deportes</a></li>,
# ...

# %%
secciones = s.find('ul', attrs={'class':'horizontal-list main-sections hide-on-dropdown'}).find_all('li')
secciones
# Out:
# [<li class="p12-separator--right--primary"><a href="https://www.pagina12.com.ar/secciones/el-pais">El país</a></li>,
#  <li class="p12-separator--right--primary"><a href="https://www.pagina12.com.ar/secciones/la-ventana">La ventana</a></li>,
#  <li class="p12-separator--right--primary"><a href="https://www.pagina12.com.ar/secciones/economia">Economía</a></li>,
#  <li class="no-separator-on-1040 p12-separator--right--primary"><a href="https://www.pagina12.com.ar/secciones/sociedad">Sociedad</a></li>,
#  <li class="hide-on-1040 p12-separator--right--primary"><a href="https://www.pagina12.com.ar/suplementos/cultura-y-espectaculos">Cultura y Espectáculos</a></li>,
#  <li class="hide-on-1040 p12-separator--right--primary"><a href="https://www.pagina12.com.ar/secciones/el-mundo">El mundo</a></li>,
#  <li class="hide-on-1040 p12-separator--right--primary"><a href="https://www.pagina12.com.ar/secciones/deportes">Deportes</a></li>,
# ...

# %%
type(secciones)
# Out:
# bs4.element.ResultSet

# %%
type(secciones)
# Out:
# bs4.element.ResultSet

# %%
seccion = secciones[0]
seccion
# Out:
# <li class="p12-separator--right--primary"><a href="https://www.pagina12.com.ar/secciones/el-pais">El país</a></li>

# %%
type(seccion)
# Out:
# bs4.element.Tag

# %%
seccion.find('a')
# Out:
# <a href="https://www.pagina12.com.ar/secciones/el-pais">El país</a>

# %%
# Instrucción equivalente
seccion.a
# Out:
# <a href="https://www.pagina12.com.ar/secciones/el-pais">El país</a>

# %%
# Obtener el atributo href
seccion.a.get('href')
# Out:
# 'https://www.pagina12.com.ar/secciones/el-pais'

# %%
# Obtener el texto
seccion.a.get_text()
# Out:
# 'El país'

# %%
# Obtener el atributo href y almacenarlo con un ciclo

links_secciones = [seccion.a.get('href') for seccion in secciones]
links_secciones
# Out:
# ['https://www.pagina12.com.ar/secciones/el-pais',
#  'https://www.pagina12.com.ar/secciones/la-ventana',
#  'https://www.pagina12.com.ar/secciones/economia',
#  'https://www.pagina12.com.ar/secciones/sociedad',
#  'https://www.pagina12.com.ar/suplementos/cultura-y-espectaculos',
#  'https://www.pagina12.com.ar/secciones/el-mundo',
#  'https://www.pagina12.com.ar/secciones/deportes',
#  'https://www.pagina12.com.ar/secciones/plastica']

# %% [markdown]
# ## Ahora, obtendremos solo el primer link para buscar las noticias

# %%
# Obtener el primer link
sec = requests.get(links_secciones[0])
sec
# Out:
# <Response [200]>

# %%
s_seccion = BeautifulSoup(sec.text, 'lxml')

# %%
type(s_seccion)
# Out:
# bs4.BeautifulSoup

# %%
print(s_seccion.prettify())
# Out:
# <!DOCTYPE html>
# <html amp="" lang="es">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    El país | Página12
#   </title>
#   <!-- DUST PATH: /usr/src/app/src/widgets/fc_jsonLD.dust/ -->
#   <script type="application/ld+json">
#    {"@context": "http://schema.org","@type": "BreadcrumbList","itemListElement": [{"@type": "ListItem","position": 1,"name": "","item": ""},{"@type": "ListItem","position": 2,"name": "","item": ""}]}
#   </script>
#   <script type="application/ld+json">
# ...

# %%
featured_article = s_seccion.find('div', attrs={'class':'article-item__content-footer-wrapper gutter-small deco-bar-here-left is-mobile-top'})
featured_article
# Out:
# <div class="article-item__content-footer-wrapper gutter-small deco-bar-here-left is-mobile-top"><div class="article-item__content"><!-- Title --><h2 class="title-list"><a href="https://www.pagina12.com.ar/293966-el-gobierno-de-la-ciudad-tendra-que-explicar-los-gastos-dura">El Gobierno de la Ciudad tendrá que explicar los gastos durante pandemia </a></h2><!-- Kicker --><p><a href="https://www.pagina12.com.ar/293966-el-gobierno-de-la-ciudad-tendra-que-explicar-los-gastos-dura">Reclaman la presencia de funcionarios porteños en la Legislatura</a></p></div><div class="article-item__footer"><!-- Date --><div class="date">22 de septiembre de 2020</div></div></div>

# %%
type(featured_article)
# Out:
# bs4.element.Tag

# %%
featured_article.a.get('href')
# Out:
# 'https://www.pagina12.com.ar/293966-el-gobierno-de-la-ciudad-tendra-que-explicar-los-gastos-dura'

# %% [markdown]
# ## Obtener el resto de urls de las noticias

# %% [markdown]
# ### Clase 06 Extrayendo información

# %%
# El 22Sep2020, la URL muestra una estructura diferente
# Parece que las noticias dentro de cada link, por ejemplo en https://www.pagina12.com.ar/secciones/el-pais
# las noticias se dividen en tres tipos, dentro de cada una de las siguientes tag <section> y <div>
#    <section class="top-content">
#    <section class="list-content">
    # Aquí, a su vez hay dos tipos
#        <div class="articles-list is-grid-col2 grid-mobile-row">
#        <div class="articles-list">

# Una noticia se mantiene en la parte superior, dos noticias tienen título h3, el resto h4

# %% [markdown]
# # RETO Clase 06

# %% [markdown]
# ## Obteniendo href de la noticia en "top-content"

# %%
import requests

# %%
# Obtener el primer link
resultado_request = requests.get('https://www.pagina12.com.ar/secciones/el-pais')
resultado_request
# Out:
# <Response [200]>

# %%
type(resultado_request)
# Out:
# requests.models.Response

# %%
from bs4 import BeautifulSoup

# %%
s = BeautifulSoup(resultado_request.text, 'lxml')

# %%
type(s)
# Out:
# bs4.BeautifulSoup

# %%
print(s.prettify())
# Out:
# <!DOCTYPE html>
# <html amp="" lang="es">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    El país | Página12
#   </title>
#   <!-- DUST PATH: /usr/src/app/src/widgets/fc_jsonLD.dust/ -->
#   <script type="application/ld+json">
#    {"@context": "http://schema.org","@type": "BreadcrumbList","itemListElement": [{"@type": "ListItem","position": 1,"name": "","item": ""},{"@type": "ListItem","position": 2,"name": "","item": ""}]}
#   </script>
#   <script type="application/ld+json">
# ...

# %%
top_article = s.find('div', attrs={'class': 'article-item__content'})
top_article
# Out:
# <div class="article-item__content"><!-- Title --><h2 class="title-list"><a href="https://www.pagina12.com.ar/293966-el-gobierno-de-la-ciudad-tendra-que-explicar-los-gastos-dura">El Gobierno de la Ciudad tendrá que explicar los gastos durante pandemia </a></h2><!-- Kicker --><p><a href="https://www.pagina12.com.ar/293966-el-gobierno-de-la-ciudad-tendra-que-explicar-los-gastos-dura">Reclaman la presencia de funcionarios porteños en la Legislatura</a></p></div>

# %%
type(top_article)
# Out:
# bs4.element.Tag

# %%
top_article_link = top_article.a.get('href')
top_article_link
# Out:
# 'https://www.pagina12.com.ar/293966-el-gobierno-de-la-ciudad-tendra-que-explicar-los-gastos-dura'

# %%
type(top_article_link)
# Out:
# str

# %%
top_article_title = top_article.a.get_text()
top_article_title
# Out:
# 'El Gobierno de la Ciudad tendrá que explicar los gastos durante pandemia\xa0'

# %%
dictionary_noticias = []

dictionary_noticias.append((top_article_title, top_article_link))
dictionary_noticias
# Out:
# [('El Gobierno de la Ciudad tendrá que explicar los gastos durante pandemia\xa0',
#   'https://www.pagina12.com.ar/293966-el-gobierno-de-la-ciudad-tendra-que-explicar-los-gastos-dura')]

# %% [markdown]
# ## Obteniendo href de las noticias tipo h3

# %%
lista_h3 = s.find_all('h3', attrs={'class': 'title-list'})
lista_h3
# Out:
# [<h3 class="title-list"><a href="https://www.pagina12.com.ar/293959-dia-internacional-contra-la-explotacion-sexual-y-el-trafico-">Día internacional contra la explotación sexual y el tráfico de mujeres, niñas y niños</a></h3>,
#  <h3 class="title-list"><a href="https://www.pagina12.com.ar/293952-avanza-en-diputados-la-imprescriptibilidad-de-los-resarcimie">Avanza en Diputados la imprescriptibilidad de los resarcimientos por crímenes de lesa humanidad</a></h3>]

# %%
lista_links_seccion1 = [link.a.get('href') for link in lista_h3]
lista_links_seccion1
# Out:
# ['https://www.pagina12.com.ar/293959-dia-internacional-contra-la-explotacion-sexual-y-el-trafico-',
#  'https://www.pagina12.com.ar/293952-avanza-en-diputados-la-imprescriptibilidad-de-los-resarcimie']

# %%
lista_titles_seccion1 = [link.a.get_text() for link in lista_h3]
lista_titles_seccion1
# Out:
# ['Día internacional contra la explotación sexual y el tráfico de mujeres, niñas y niños',
#  'Avanza en Diputados la imprescriptibilidad de los resarcimientos por crímenes de lesa humanidad']

# %% [markdown]
# ## Buscamos el resto de noticias, ahora de tag h4

# %%
lista_h4 = s.find_all('h4', attrs={'class': 'title-list'})
lista_h4
# Out:
# [<h4 class="is-display-inline title-list"><a class="" href="https://www.pagina12.com.ar/293949-volver-a-clases-pero-no-de-cualquier-manera">Volver a clases, pero no de cualquier manera</a></h4>,
#  <h4 class="is-display-inline title-list"><a class="" href="https://www.pagina12.com.ar/293948-cafiero-birndara-su-tercer-informe-en-el-congreso">Cafiero birndará su tercer informe en el Congreso</a></h4>,
#  <h4 class="is-display-inline title-list"><a class="" href="https://www.pagina12.com.ar/293937-lesa-humanidad-continua-el-juicio-12-de-cordoba">Lesa humanidad: continúa el juicio 12 de Córdoba</a></h4>,
#  <h4 class="is-display-inline title-list"><a class="" href="https://www.pagina12.com.ar/293925-alberto-fernandez-ante-la-onu-la-vacuna-contra-el-coronaviru">Alberto Fernández ante la ONU: "La vacuna contra el coronavirus tiene que ser un bien público global"</a></h4>,
# ...

# %%
lista_links_seccion2 = [link.a.get('href') for link in lista_h4]
lista_links_seccion2
# Out:
# ['https://www.pagina12.com.ar/293949-volver-a-clases-pero-no-de-cualquier-manera',
#  'https://www.pagina12.com.ar/293948-cafiero-birndara-su-tercer-informe-en-el-congreso',
#  'https://www.pagina12.com.ar/293937-lesa-humanidad-continua-el-juicio-12-de-cordoba',
#  'https://www.pagina12.com.ar/293925-alberto-fernandez-ante-la-onu-la-vacuna-contra-el-coronaviru',
#  'https://www.pagina12.com.ar/293910-toma-de-tierras-en-guernica-la-justicia-postergo-el-desalojo',
#  'https://www.pagina12.com.ar/293909-una-pedagogia-de-la-crueldad',
#  'https://www.pagina12.com.ar/293892-diego-santilli-se-aislo-tras-estar-en-contacto-con-una-perso',
#  'https://www.pagina12.com.ar/293884-los-problemas-de-salud-de-macri-durante-su-presidencia']

# %%
lista_titles_seccion2 = [link.a.get_text() for link in lista_h4]
lista_titles_seccion2
# Out:
# ['Volver a clases, pero no de cualquier manera',
#  'Cafiero birndará su tercer informe en el Congreso',
#  'Lesa humanidad: continúa el juicio 12 de Córdoba',
#  'Alberto Fernández ante la ONU: "La vacuna contra el coronavirus tiene que ser un bien público global"',
#  'Toma de tierras en Guernica: la Justicia postergó el desalojo',
#  'Una pedagogía de la crueldad',
#  'Diego Santilli se aisló tras estar en contacto con una persona con coronavirus\xa0',
#  'Los problemas de salud de Macri durante su presidencia']

# %%
# Juntamos todos los links

lista_links = [top_article_link] + lista_links_seccion1 + lista_links_seccion2
lista_links
# Out:
# ['https://www.pagina12.com.ar/293966-el-gobierno-de-la-ciudad-tendra-que-explicar-los-gastos-dura',
#  'https://www.pagina12.com.ar/293959-dia-internacional-contra-la-explotacion-sexual-y-el-trafico-',
#  'https://www.pagina12.com.ar/293952-avanza-en-diputados-la-imprescriptibilidad-de-los-resarcimie',
#  'https://www.pagina12.com.ar/293949-volver-a-clases-pero-no-de-cualquier-manera',
#  'https://www.pagina12.com.ar/293948-cafiero-birndara-su-tercer-informe-en-el-congreso',
#  'https://www.pagina12.com.ar/293937-lesa-humanidad-continua-el-juicio-12-de-cordoba',
#  'https://www.pagina12.com.ar/293925-alberto-fernandez-ante-la-onu-la-vacuna-contra-el-coronaviru',
#  'https://www.pagina12.com.ar/293910-toma-de-tierras-en-guernica-la-justicia-postergo-el-desalojo',
#  'https://www.pagina12.com.ar/293909-una-pedagogia-de-la-crueldad',
#  'https://www.pagina12.com.ar/293892-diego-santilli-se-aislo-tras-estar-en-contacto-con-una-perso',
# ...

# %% [markdown]
# ## Resolviendo el reto: Crear una función que reciba un soup y obtenga los links a las noticias

# %% [markdown]
# ### Usaremos las instrucciones anteriores para armar la función

# %%
def fnt_obtener_links(s):
    top_article = s.find('div', attrs={'class': 'article-item__content'})
    top_article_link = top_article.a.get('href')
    
    lista_h3 = s.find_all('h3', attrs={'class': 'title-list'})
    lista_links_seccion1 = [link.a.get('href') for link in lista_h3]
    
    lista_h4 = s.find_all('h4', attrs={'class': 'title-list'})
    lista_links_seccion2 = [link.a.get('href') for link in lista_h4]
    
    lista_links = [top_article_link] + lista_links_seccion1 + lista_links_seccion2
    
    return lista_links

import requests
from bs4 import BeautifulSoup

# resultado_request = requests.get('https://www.pagina12.com.ar/secciones/el-pais')
resultado_request = requests.get('https://www.pagina12.com.ar/secciones/economia')

s = BeautifulSoup(resultado_request.text, 'lxml') 

fnt_obtener_links(s)
# Out:
# ['https://www.pagina12.com.ar/293956-una-lista-de-los-que-se-quedan-a-invertir',
#  'https://www.pagina12.com.ar/293943-tarifas-abusivas-en-buenos-aires',
#  'https://www.pagina12.com.ar/293939-nos-recomponemos-de-un-industricidio',
#  'https://www.pagina12.com.ar/293935-paritarias-a-fuego-lento',
#  'https://www.pagina12.com.ar/293931-jubilados-septiembre-2020-quienes-cobran-este-miercoles-23',
#  'https://www.pagina12.com.ar/293930-asignacion-universal-por-embarazo-septiembre-2020-quienes-co',
#  'https://www.pagina12.com.ar/288274-asignacion-universal-por-embarazo-septiembre-2020-la-anses-f',
#  'https://www.pagina12.com.ar/288267-jubilados-septiembre-2020-la-anses-fijo-las-fechas-de-cobro',
#  'https://www.pagina12.com.ar/293894-el-pbi-cayo-el-19-1-en-segundo-trimestre-del-ano',
#  'https://www.pagina12.com.ar/293879-martin-guzman-expone-el-proyecto-de-presupuesto-2021-ante-lo',
#  'https://www.pagina12.com.ar/293853-como-son-los-nuevos-creditos-para-electrodomesticos-que-lanz']

# %%
def obtener_notas(soup):
    lista_notas = []
    
    featured_article = soup.find('div', attrs={'class': 'article-item__content'})
    if featured_article:
        try:
            lista_notas.append(featured_article.a.get('href'))
        except Exception as e:
            print('Ocurrió un error, parte A')
            print(featured_article)
            print(e)
            print('\n')
    
    article_list1 = soup.find_all('h3', attrs={'class': 'title-list'})
    for article in article_list1:
        if article.a:
            try:
                lista_notas.append(article.a.get('href'))
            except Exception as e:
                print('Ocurrió un error, parte B')
                print(article)
                print(e)
                print('\n')
            
    article_list2 = soup.find_all('h4', attrs={'class': 'title-list'})
    for article in article_list2:
        if article.a:
            try:
                lista_notas.append(article.a.get('href'))
            except Exception as e:
                print('Ocurrió un error, parte C')
                print(article)
                print(e)
                print('\n')
            
    return lista_notas

# %%
import requests
from bs4 import BeautifulSoup

resultado_request = requests.get('https://www.pagina12.com.ar/secciones/el-pais')
#resultado_request = requests.get('https://www.pagina12.com.ar/secciones/economia')

s = BeautifulSoup(resultado_request.text, 'lxml') 

lista_notas = obtener_notas(s)
lista_notas
# Out:
# ['https://www.pagina12.com.ar/294003-acto-de-apoyo-por-el-17-de-octubre',
#  'https://www.pagina12.com.ar/294009-juntos-por-el-cambio-pide-sesiones-presenciales-para-el-pres',
#  'https://www.pagina12.com.ar/294017-desdolarizar-la-vivienda',
#  'https://www.pagina12.com.ar/293910-toma-de-tierras-en-guernica-la-justicia-postergo-el-desalojo',
#  'https://www.pagina12.com.ar/293756-alberto-fernandez-ante-la-onu-la-vacuna-contra-el-coronaviru',
#  'https://www.pagina12.com.ar/293948-cafiero-birndara-su-tercer-informe-en-el-congreso',
#  'https://www.pagina12.com.ar/293949-volver-a-clases-pero-no-de-cualquier-manera',
#  'https://www.pagina12.com.ar/293952-avanza-en-diputados-la-imprescriptibilidad-de-los-resarcimie',
#  'https://www.pagina12.com.ar/293959-dia-internacional-contra-la-explotacion-sexual-y-el-trafico-',
#  'https://www.pagina12.com.ar/293966-el-gobierno-de-la-ciudad-tendra-que-explicar-los-gastos-dura',
# ...
